# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
from dash.dependencies import Input, Output

# %%
import pandas as pd
import numpy as np
from plotly.subplots import make_subplots

# %%
sd = pd.read_csv("cleaned_dat_500.csv")
boroughs = ['Brooklyn', 'Manhattan']

# %%
count=[]
list=[]

for i in range(len(boroughs)):
     count.append(sd.neighbourhood_group[((sd.room_type == 'Entire home/apt') and (sd.neighbourhood_group == i))]

# for j in count:
#     for k in j:
#         list.append(k)
        
# print(len(count[0])+len(count[1]))
# print(list)
# Out:
#   File "<ipython-input-76-2ddc91f4cda2>", line 7
#     for j in count:
#                   ^
# SyntaxError: invalid syntax

# %%
app = dash.Dash()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-89a58a9eb56f> in <module>
# ----> 1 app = dash.Dash()
#
# NameError: name 'dash' is not defined

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app.layout = html.Div(children = [
    
    html.H1("NYC AirBnb data", style={"textAlign": "center", "fontColor" : "blue"}),
  
    html.Div(children = [
        
        dcc.Checklist(
            id ='checklist', 
            options=[
                {'label': i, 'value': i} for i in sd.neighbourhood_group.unique()],
            value=[]
        ),
        
        
        html.Div(children = [
            dcc.Graph(
                id='graph11',
                figure={
                    'data':[
                        go.Scatter(
                        x = sd.reviews_per_month, 
                        y = sd.price, 
#                         text = sd.index,
#                         selectedpoints = 'selectedpoints',
#                         customdata = sd.index,
                        mode = 'markers',
                        marker={
                            'size': 7,
                            'opacity': 0.7,
                            'line': {'width': 0.5, 'color': 'white'}
                        }, 
                       )
                    ], 
                    'layout':go.Layout(
                        title = 'Reviews per Month Vs Price', 
                        xaxis = {'title':'Reviews Per Month'}, 
                        yaxis = {'title':'price'}, 
                        hovermode = 'closest',
                    )
                }
            )
        ], className = 'column', style={'display': 'inline-block'}),
        
        html.Div(children = [
            dcc.Graph(
                id='graph12',
                figure={
                    'data':[
                        go.Scatter(
                        x = sd.longitude, 
                        y = sd.latitude, 
                        mode = 'markers', 
                        marker={
                            'size': 7,
                            'opacity': 0.7,
                            'line': {'width': 0.5, 'color': 'white'}
                        })
                    ], 
                    'layout':go.Layout(
                        title = 'Longitude Vs Latitude', 
                        xaxis = {'title':'Longitude'}, 
                        yaxis = {'title':'Latitude'}, 
                        hovermode = 'closest'
                    )
                }
            )
        ], className = 'column', style={'align': 'right', 'display': 'inline-block'}),  
        
    ], className = 'row'), 
    
    html.Div(children = [
            
        html.Div(children = [
                dcc.Graph(
                    id='graph21',
                    figure={
                        "data": [
                            go.Pie(
                                labels = sd.neighbourhood_group.unique(), 
                                values= sd.neighbourhood_group.value_counts(),
                                hole=0.4,
                                marker={'colors': ['#EF963B', '#C93277', '#349600', '#EF533B', '#57D4F1'], 
                                    }, 
                                textinfo='label')],

                        "layout": go.Layout(title="Neighbourhood boroughs", 
#                                 margin={"l": 300, "r": 300, },
                                legend={"x": 1, "y": 0.7})
                    }

                )

            ], className = 'column', style={'display': 'inline-block'}),
            
            html.Div(children = [
                dcc.Graph(
                    id='graph22',
                    figure={
                        "data":[
                            
                            {'x':sd.neighbourhood_group.unique(), 
                             'y':sd.neighbourhood_group[sd.room_type == 'Private room'].value_counts(), 
                             'name':"Private Room", 
                             'type':'bar'}, 
                            
                            {'x':sd.neighbourhood_group.unique(), 
                             'y':sd.neighbourhood_group[sd.room_type == 'Entire home/apt'].value_counts(), 
                             'name':'Entire home/apt', 
                             'type':'bar'}, 
                            
                            {'x':sd.neighbourhood_group.unique(), 
                             'y':sd.neighbourhood_group[sd.room_type == 'Shared room'].value_counts(), 
                             'name':'Shared room', 
                             'type':'bar'}, 
                        
                        ],

                        "layout": go.Layout(title="Neighbourhood boroughs #2",)
                    }

                )

            ], className = 'column', style={'align': 'right', 'display': 'inline-block'}),

        ], className = 'row'),
    
],style={'textAlign':'center'})

@app.callback(Output('graph21', 'figure'), 
             Input('checklist', 'value'))
def update_dashboard(boroughs):
    figure={
        "data": [
            go.Pie(
                labels = sd.neighbourhood_group[sd.neighbourhood_group.unique() == boroughs], 
                values= sd.neighbourhood_group.value_counts(),
                hole= 0.4,
                marker={'colors': ['#EF963B', '#C93277', '#349600', '#EF533B', '#57D4F1'], 
                    }, 
                textinfo='label')],

        "layout": go.Layout(title="Neighbourhood boroughs", 
#                                 margin={"l": 300, "r": 300, },
                legend={"x": 1, "y": 0.7})
    }
   
    return figure
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-91fe8146c54a> in <module>
#       1 external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
# ----> 2 app.layout = html.Div(children = [
#       3
#       4     html.H1("NYC AirBnb data", style={"textAlign": "center", "fontColor" : "blue"}),
#       5
#
# NameError: name 'html' is not defined

# %%
if __name__ == '__main__':
    app.run_server(port = 2022)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-c88787e319ca> in <module>
#       1 if __name__ == '__main__':
# ----> 2     app.run_server(port = 2022)
#       3
#
# NameError: name 'app' is not defined

# %%
# help(html)
# Out:
# Help on package dash_html_components:
#
# NAME
#     dash_html_components - Vanilla HTML components for Dash
#
# PACKAGE CONTENTS
#     A
#     Abbr
#     Acronym
#     Address
#     Area
#     Article
#     Aside
#     Audio
#     B
#     Base
#     Basefont
#     Bdi
#     Bdo
#     Big
#     Blink
#     Blockquote
#     Br
#     Button
#     Canvas
#     Caption
#     Center
#     Cite
#     Code
#     Col
#     Colgroup
#     Command
#     Content
#     Data
#     Datalist
#     Dd
#     Del
#     Details
#     Dfn
#     Dialog
#     Div
#     Dl
#     Dt
#     Element
#     Em
#     Embed
#     Fieldset
#     Figcaption
#     Figure
#     Font
#     Footer
#     Form
#     Frame
#     Frameset
#     H1
#     H2
#     H3
#     H4
#     H5
#     H6
#     Header
#     Hgroup
#     Hr
#     I
#     Iframe
#     Img
#     Ins
#     Isindex
#     Kbd
#     Keygen
#     Label
#     Legend
#     Li
#     Link
#     Listing
#     Main
#     MapEl
#     Mark
#     Marquee
#     Meta
#     Meter
#     Multicol
#     Nav
#     Nextid
#     Nobr
#     Noscript
#     ObjectEl
#     Ol
#     Optgroup
#     Option
#     Output
#     P
#     Param
#     Picture
#     Plaintext
#     Pre
#     Progress
#     Q
#     Rb
#     Rp
#     Rt
#     Rtc
#     Ruby
#     S
#     Samp
#     Script
#     Section
#     Select
#     Shadow
#     Slot
#     Small
#     Source
#     Spacer
#     Span
#     Strike
#     Strong
#     Sub
#     Summary
#     Sup
#     Table
#     Tbody
#     Td
#     Template
#     Textarea
#     Tfoot
#     Th
#     Thead
#     Time
#     Title
#     Tr
#     Track
#     U
#     Ul
#     Var
#     Video
#     Wbr
#     Xmp
#     _imports_
#
# CLASSES
#     dash.development.base_component.Component(builtins.object)
#         dash_html_components.A.A
#         dash_html_components.Abbr.Abbr
#         dash_html_components.Acronym.Acronym
#         dash_html_components.Address.Address
#         dash_html_components.Area.Area
#         dash_html_components.Article.Article
#         dash_html_components.Aside.Aside
#         dash_html_components.Audio.Audio
#         dash_html_components.B.B
#         dash_html_components.Base.Base
#         dash_html_components.Basefont.Basefont
#         dash_html_components.Bdi.Bdi
#         dash_html_components.Bdo.Bdo
#         dash_html_components.Big.Big
#         dash_html_components.Blink.Blink
#         dash_html_components.Blockquote.Blockquote
#         dash_html_components.Br.Br
#         dash_html_components.Button.Button
#         dash_html_components.Canvas.Canvas
#         dash_html_components.Caption.Caption
#         dash_html_components.Center.Center
#         dash_html_components.Cite.Cite
#         dash_html_components.Code.Code
#         dash_html_components.Col.Col
#         dash_html_components.Colgroup.Colgroup
#         dash_html_components.Command.Command
#         dash_html_components.Content.Content
#         dash_html_components.Data.Data
#         dash_html_components.Datalist.Datalist
#         dash_html_components.Dd.Dd
#         dash_html_components.Del.Del
#         dash_html_components.Details.Details
#         dash_html_components.Dfn.Dfn
#         dash_html_components.Dialog.Dialog
#         dash_html_components.Div.Div
#         dash_html_components.Dl.Dl
#         dash_html_components.Dt.Dt
#         dash_html_components.Element.Element
#         dash_html_components.Em.Em
#         dash_html_components.Embed.Embed
#         dash_html_components.Fieldset.Fieldset
#         dash_html_components.Figcaption.Figcaption
#         dash_html_components.Figure.Figure
#         dash_html_components.Font.Font
#         dash_html_components.Footer.Footer
#         dash_html_components.Form.Form
#         dash_html_components.Frame.Frame
#         dash_html_components.Frameset.Frameset
#         dash_html_components.H1.H1
#         dash_html_components.H2.H2
#         dash_html_components.H3.H3
#         dash_html_components.H4.H4
#         dash_html_components.H5.H5
#         dash_html_components.H6.H6
#         dash_html_components.Header.Header
#         dash_html_components.Hgroup.Hgroup
#         dash_html_components.Hr.Hr
#         dash_html_components.I.I
#         dash_html_components.Iframe.Iframe
#         dash_html_components.Img.Img
#         dash_html_components.Ins.Ins
#         dash_html_components.Isindex.Isindex
#         dash_html_components.Kbd.Kbd
#         dash_html_components.Keygen.Keygen
#         dash_html_components.Label.Label
#         dash_html_components.Legend.Legend
#         dash_html_components.Li.Li
#         dash_html_components.Link.Link
#         dash_html_components.Listing.Listing
#         dash_html_components.Main.Main
#         dash_html_components.MapEl.MapEl
#         dash_html_components.Mark.Mark
#         dash_html_components.Marquee.Marquee
#         dash_html_components.Meta.Meta
#         dash_html_components.Meter.Meter
#         dash_html_components.Multicol.Multicol
#         dash_html_components.Nav.Nav
#         dash_html_components.Nextid.Nextid
#         dash_html_components.Nobr.Nobr
#         dash_html_components.Noscript.Noscript
#         dash_html_components.ObjectEl.ObjectEl
#         dash_html_components.Ol.Ol
#         dash_html_components.Optgroup.Optgroup
#         dash_html_components.Option.Option
#         dash_html_components.Output.Output
#         dash_html_components.P.P
#         dash_html_components.Param.Param
#         dash_html_components.Picture.Picture
#         dash_html_components.Plaintext.Plaintext
#         dash_html_components.Pre.Pre
#         dash_html_components.Progress.Progress
#         dash_html_components.Q.Q
#         dash_html_components.Rb.Rb
#         dash_html_components.Rp.Rp
#         dash_html_components.Rt.Rt
#         dash_html_components.Rtc.Rtc
#         dash_html_components.Ruby.Ruby
#         dash_html_components.S.S
#         dash_html_components.Samp.Samp
#         dash_html_components.Script.Script
#         dash_html_components.Section.Section
#         dash_html_components.Select.Select
#         dash_html_components.Shadow.Shadow
#         dash_html_components.Slot.Slot
#         dash_html_components.Small.Small
#         dash_html_components.Source.Source
#         dash_html_components.Spacer.Spacer
#         dash_html_components.Span.Span
#         dash_html_components.Strike.Strike
#         dash_html_components.Strong.Strong
#         dash_html_components.Sub.Sub
#         dash_html_components.Summary.Summary
#         dash_html_components.Sup.Sup
#         dash_html_components.Table.Table
#         dash_html_components.Tbody.Tbody
#         dash_html_components.Td.Td
#         dash_html_components.Template.Template
#         dash_html_components.Textarea.Textarea
#         dash_html_components.Tfoot.Tfoot
#         dash_html_components.Th.Th
#         dash_html_components.Thead.Thead
#         dash_html_components.Time.Time
#         dash_html_components.Title.Title
#         dash_html_components.Tr.Tr
#         dash_html_components.Track.Track
#         dash_html_components.U.U
#         dash_html_components.Ul.Ul
#         dash_html_components.Var.Var
#         dash_html_components.Video.Video
#         dash_html_components.Wbr.Wbr
#         dash_html_components.Xmp.Xmp
#
#     class A(dash.development.base_component.Component)
#      |  A(children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, download=undefined, href=undefined, hrefLang=undefined, media=undefined, rel=undefined, shape=undefined, target=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  An A component.
#      |  A is a wrapper for the <a> HTML5 element.
#      |  For detailed attribute info see:
#      |  https://developer.mozilla.org/en-US/docs/Web/HTML/Element/a
#      |
#      |  Keyword arguments:
#      |  - children (a list of or a singular dash component, string or number; optional): The children of this component
#      |  - id (string; optional): The ID of this component, used to identify dash components
#      |  in callbacks. The ID needs to be unique across all of the
#      |  components in an app.
#      |  - n_clicks (number; default 0): An integer that represents the number of times
#      |  that this element has been clicked on.
#      |  - n_clicks_timestamp (number; default -1): An integer that represents the time (in ms since 1970)
#      |  at which n_clicks changed. This can be used to tell
#      |  which button was changed most recently.
#      |  - key (string; optional): A unique identifier for the component, used to improve
#      |  performance by React.js while rendering components
#      |  See https://reactjs.org/docs/lists-and-keys.html for more info
#      |  - role (string; optional): The ARIA role attribute
#      |  - data-* (string; optional): A wildcard data attribute
#      |  - aria-* (string; optional): A wildcard aria attribute
#      |  - download (string; optional): Indicates that the hyperlink is to be used for downloading a resource.
#      |  - href (string; optional): The URL of a linked resource.
#      |  - hrefLang (string; optional): Specifies the language of the linked resource.
#      |  - media (string; optional): Specifies a hint of the media for which the linked resource was designed.
#      |  - rel (string; optional): Specifies the relationship of the target object to the link object.
#      |  - shape (string; optional)
#      |  - target (string; optional)
#      |  - accessKey (string; optional): Defines a keyboard shortcut to activate or add focus to the element.
#      |  - className (string; optional): Often used with CSS to style elements with common properties.
#      |  - contentEditable (string; optional): Indicates whether the element's content is editable.
#      |  - contextMenu (string; optional): Defines the ID of a <menu> element which will serve as the element's context menu.
#      |  - dir (string; optional): Defines the text direction. Allowed values are ltr (Left-To-Right) or rtl (Right-To-Left)
#      |  - draggable (string; optional): Defines whether the element can be dragged.
#      |  - hidden (a value equal to: 'hidden', 'HIDDEN' | boolean; optional): Prevents rendering of given element, while keeping child elements, e.g. script elements, active.
#      |  - lang (string; optional): Defines the language used in the element.
#      |  - spellCheck (string; optional): Indicates whether spell checking is allowed for the element.
#      |  - style (dict; optional): Defines CSS styles which will override styles previously set.
#      |  - tabIndex (string; optional): Overrides the browser's default tab order and follows the one specified instead.
#      |  - title (string; optional): Text to be displayed in a tooltip when hovering over the element.
#      |  - loading_state (dict; optional): Object that holds the loading state object coming from dash-renderer. loading_state has the following type: dict containing keys 'is_loading', 'prop_name', 'component_name'.
#      |  Those keys have the following types:
#      |    - is_loading (boolean; optional): Determines if the component is loading or not
#      |    - prop_name (string; optional): Holds which property is loading
#      |    - component_name (string; optional): Holds the name of the component that is loading
#      |
#      |  Method resolution order:
#      |      A
#      |      dash.development.base_component.Component
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__ = wrapper(self, children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, download=undefined, href=undefined, hrefLang=undefined, media=undefined, rel=undefined, shape=undefined, target=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from dash.development.base_component.Component:
#      |
#      |  __delitem__(self, id)
#      |      Delete items by ID in the tree of children.
#      |
#      |  __getitem__(self, id)
#      |      Recursively find the element with the given ID through the tree of
#      |      children.
#      |
#      |  __iter__(self)
#      |      Yield IDs in the tree of children.
#      |
#      |  __len__(self)
#      |      Return the number of items in the tree.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __setitem__(self, id, item)
#      |      Set an element by its ID.
#      |
#      |  to_plotly_json(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from dash.development.base_component.Component:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from dash.development.base_component.Component:
#      |
#      |  REQUIRED = required
#      |
#      |  UNDEFINED = undefined
#
#     class Abbr(dash.development.base_component.Component)
#      |  Abbr(children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  An Abbr component.
#      |  Abbr is a wrapper for the <abbr> HTML5 element.
#      |  For detailed attribute info see:
#      |  https://developer.mozilla.org/en-US/docs/Web/HTML/Element/abbr
#      |
#      |  Keyword arguments:
#      |  - children (a list of or a singular dash component, string or number; optional): The children of this component
#      |  - id (string; optional): The ID of this component, used to identify dash components
#      |  in callbacks. The ID needs to be unique across all of the
#      |  components in an app.
#      |  - n_clicks (number; default 0): An integer that represents the number of times
#      |  that this element has been clicked on.
#      |  - n_clicks_timestamp (number; default -1): An integer that represents the time (in ms since 1970)
#      |  at which n_clicks changed. This can be used to tell
#      |  which button was changed most recently.
#      |  - key (string; optional): A unique identifier for the component, used to improve
#      |  performance by React.js while rendering components
#      |  See https://reactjs.org/docs/lists-and-keys.html for more info
#      |  - role (string; optional): The ARIA role attribute
#      |  - data-* (string; optional): A wildcard data attribute
#      |  - aria-* (string; optional): A wildcard aria attribute
#      |  - accessKey (string; optional): Defines a keyboard shortcut to activate or add focus to the element.
#      |  - className (string; optional): Often used with CSS to style elements with common properties.
#      |  - contentEditable (string; optional): Indicates whether the element's content is editable.
#      |  - contextMenu (string; optional): Defines the ID of a <menu> element which will serve as the element's context menu.
#      |  - dir (string; optional): Defines the text direction. Allowed values are ltr (Left-To-Right) or rtl (Right-To-Left)
#      |  - draggable (string; optional): Defines whether the element can be dragged.
#      |  - hidden (a value equal to: 'hidden', 'HIDDEN' | boolean; optional): Prevents rendering of given element, while keeping child elements, e.g. script elements, active.
#      |  - lang (string; optional): Defines the language used in the element.
#      |  - spellCheck (string; optional): Indicates whether spell checking is allowed for the element.
#      |  - style (dict; optional): Defines CSS styles which will override styles previously set.
#      |  - tabIndex (string; optional): Overrides the browser's default tab order and follows the one specified instead.
#      |  - title (string; optional): Text to be displayed in a tooltip when hovering over the element.
#      |  - loading_state (dict; optional): Object that holds the loading state object coming from dash-renderer. loading_state has the following type: dict containing keys 'is_loading', 'prop_name', 'component_name'.
#      |  Those keys have the following types:
#      |    - is_loading (boolean; optional): Determines if the component is loading or not
#      |    - prop_name (string; optional): Holds which property is loading
#      |    - component_name (string; optional): Holds the name of the component that is loading
#      |
#      |  Method resolution order:
#      |      Abbr
#      |      dash.development.base_component.Component
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__ = wrapper(self, children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from dash.development.base_component.Component:
#      |
#      |  __delitem__(self, id)
#      |      Delete items by ID in the tree of children.
#      |
#      |  __getitem__(self, id)
#      |      Recursively find the element with the given ID through the tree of
#      |      children.
#      |
#      |  __iter__(self)
#      |      Yield IDs in the tree of children.
#      |
#      |  __len__(self)
#      |      Return the number of items in the tree.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __setitem__(self, id, item)
#      |      Set an element by its ID.
#      |
#      |  to_plotly_json(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from dash.development.base_component.Component:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from dash.development.base_component.Component:
#      |
#      |  REQUIRED = required
#      |
#      |  UNDEFINED = undefined
#
#     class Acronym(dash.development.base_component.Component)
#      |  Acronym(children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  An Acronym component.
#      |  Acronym is a wrapper for the <acronym> HTML5 element.
#      |  For detailed attribute info see:
#      |  https://developer.mozilla.org/en-US/docs/Web/HTML/Element/acronym
#      |
#      |  Keyword arguments:
#      |  - children (a list of or a singular dash component, string or number; optional): The children of this component
#      |  - id (string; optional): The ID of this component, used to identify dash components
#      |  in callbacks. The ID needs to be unique across all of the
#      |  components in an app.
#      |  - n_clicks (number; default 0): An integer that represents the number of times
#      |  that this element has been clicked on.
#      |  - n_clicks_timestamp (number; default -1): An integer that represents the time (in ms since 1970)
#      |  at which n_clicks changed. This can be used to tell
#      |  which button was changed most recently.
#      |  - key (string; optional): A unique identifier for the component, used to improve
#      |  performance by React.js while rendering components
#      |  See https://reactjs.org/docs/lists-and-keys.html for more info
#      |  - role (string; optional): The ARIA role attribute
#      |  - data-* (string; optional): A wildcard data attribute
#      |  - aria-* (string; optional): A wildcard aria attribute
#      |  - accessKey (string; optional): Defines a keyboard shortcut to activate or add focus to the element.
#      |  - className (string; optional): Often used with CSS to style elements with common properties.
#      |  - contentEditable (string; optional): Indicates whether the element's content is editable.
#      |  - contextMenu (string; optional): Defines the ID of a <menu> element which will serve as the element's context menu.
#      |  - dir (string; optional): Defines the text direction. Allowed values are ltr (Left-To-Right) or rtl (Right-To-Left)
#      |  - draggable (string; optional): Defines whether the element can be dragged.
#      |  - hidden (a value equal to: 'hidden', 'HIDDEN' | boolean; optional): Prevents rendering of given element, while keeping child elements, e.g. script elements, active.
#      |  - lang (string; optional): Defines the language used in the element.
#      |  - spellCheck (string; optional): Indicates whether spell checking is allowed for the element.
#      |  - style (dict; optional): Defines CSS styles which will override styles previously set.
#      |  - tabIndex (string; optional): Overrides the browser's default tab order and follows the one specified instead.
#      |  - title (string; optional): Text to be displayed in a tooltip when hovering over the element.
#      |  - loading_state (dict; optional): Object that holds the loading state object coming from dash-renderer. loading_state has the following type: dict containing keys 'is_loading', 'prop_name', 'component_name'.
#      |  Those keys have the following types:
#      |    - is_loading (boolean; optional): Determines if the component is loading or not
#      |    - prop_name (string; optional): Holds which property is loading
#      |    - component_name (string; optional): Holds the name of the component that is loading
#      |
#      |  Method resolution order:
#      |      Acronym
#      |      dash.development.base_component.Component
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__ = wrapper(self, children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from dash.development.base_component.Component:
#      |
#      |  __delitem__(self, id)
#      |      Delete items by ID in the tree of children.
#      |
#      |  __getitem__(self, id)
#      |      Recursively find the element with the given ID through the tree of
#      |      children.
#      |
#      |  __iter__(self)
#      |      Yield IDs in the tree of children.
#      |
#      |  __len__(self)
#      |      Return the number of items in the tree.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __setitem__(self, id, item)
#      |      Set an element by its ID.
#      |
#      |  to_plotly_json(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from dash.development.base_component.Component:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from dash.development.base_component.Component:
#      |
#      |  REQUIRED = required
#      |
#      |  UNDEFINED = undefined
#
#     class Address(dash.development.base_component.Component)
#      |  Address(children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  An Address component.
#      |  Address is a wrapper for the <address> HTML5 element.
#      |  For detailed attribute info see:
#      |  https://developer.mozilla.org/en-US/docs/Web/HTML/Element/address
#      |
#      |  Keyword arguments:
#      |  - children (a list of or a singular dash component, string or number; optional): The children of this component
#      |  - id (string; optional): The ID of this component, used to identify dash components
#      |  in callbacks. The ID needs to be unique across all of the
#      |  components in an app.
#      |  - n_clicks (number; default 0): An integer that represents the number of times
#      |  that this element has been clicked on.
#      |  - n_clicks_timestamp (number; default -1): An integer that represents the time (in ms since 1970)
#      |  at which n_clicks changed. This can be used to tell
#      |  which button was changed most recently.
#      |  - key (string; optional): A unique identifier for the component, used to improve
#      |  performance by React.js while rendering components
#      |  See https://reactjs.org/docs/lists-and-keys.html for more info
#      |  - role (string; optional): The ARIA role attribute
#      |  - data-* (string; optional): A wildcard data attribute
#      |  - aria-* (string; optional): A wildcard aria attribute
#      |  - accessKey (string; optional): Defines a keyboard shortcut to activate or add focus to the element.
#      |  - className (string; optional): Often used with CSS to style elements with common properties.
#      |  - contentEditable (string; optional): Indicates whether the element's content is editable.
#      |  - contextMenu (string; optional): Defines the ID of a <menu> element which will serve as the element's context menu.
#      |  - dir (string; optional): Defines the text direction. Allowed values are ltr (Left-To-Right) or rtl (Right-To-Left)
#      |  - draggable (string; optional): Defines whether the element can be dragged.
#      |  - hidden (a value equal to: 'hidden', 'HIDDEN' | boolean; optional): Prevents rendering of given element, while keeping child elements, e.g. script elements, active.
#      |  - lang (string; optional): Defines the language used in the element.
#      |  - spellCheck (string; optional): Indicates whether spell checking is allowed for the element.
#      |  - style (dict; optional): Defines CSS styles which will override styles previously set.
#      |  - tabIndex (string; optional): Overrides the browser's default tab order and follows the one specified instead.
#      |  - title (string; optional): Text to be displayed in a tooltip when hovering over the element.
#      |  - loading_state (dict; optional): Object that holds the loading state object coming from dash-renderer. loading_state has the following type: dict containing keys 'is_loading', 'prop_name', 'component_name'.
#      |  Those keys have the following types:
#      |    - is_loading (boolean; optional): Determines if the component is loading or not
#      |    - prop_name (string; optional): Holds which property is loading
#      |    - component_name (string; optional): Holds the name of the component that is loading
#      |
#      |  Method resolution order:
#      |      Address
#      |      dash.development.base_component.Component
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__ = wrapper(self, children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from dash.development.base_component.Component:
#      |
#      |  __delitem__(self, id)
#      |      Delete items by ID in the tree of children.
#      |
#      |  __getitem__(self, id)
#      |      Recursively find the element with the given ID through the tree of
#      |      children.
#      |
#      |  __iter__(self)
#      |      Yield IDs in the tree of children.
#      |
#      |  __len__(self)
#      |      Return the number of items in the tree.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __setitem__(self, id, item)
#      |      Set an element by its ID.
#      |
#      |  to_plotly_json(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from dash.development.base_component.Component:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from dash.development.base_component.Component:
#      |
#      |  REQUIRED = required
#      |
#      |  UNDEFINED = undefined
#
#     class Area(dash.development.base_component.Component)
#      |  Area(children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, alt=undefined, coords=undefined, download=undefined, href=undefined, hrefLang=undefined, media=undefined, rel=undefined, shape=undefined, target=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  An Area component.
#      |  Area is a wrapper for the <area> HTML5 element.
#      |  For detailed attribute info see:
#      |  https://developer.mozilla.org/en-US/docs/Web/HTML/Element/area
#      |
#      |  Keyword arguments:
#      |  - children (a list of or a singular dash component, string or number; optional): The children of this component
#      |  - id (string; optional): The ID of this component, used to identify dash components
#      |  in callbacks. The ID needs to be unique across all of the
#      |  components in an app.
#      |  - n_clicks (number; default 0): An integer that represents the number of times
#      |  that this element has been clicked on.
#      |  - n_clicks_timestamp (number; default -1): An integer that represents the time (in ms since 1970)
#      |  at which n_clicks changed. This can be used to tell
#      |  which button was changed most recently.
#      |  - key (string; optional): A unique identifier for the component, used to improve
#      |  performance by React.js while rendering components
#      |  See https://reactjs.org/docs/lists-and-keys.html for more info
#      |  - role (string; optional): The ARIA role attribute
#      |  - data-* (string; optional): A wildcard data attribute
#      |  - aria-* (string; optional): A wildcard aria attribute
#      |  - alt (string; optional): Alternative text in case an image can't be displayed.
#      |  - coords (string; optional): A set of values specifying the coordinates of the hot-spot region.
#      |  - download (string; optional): Indicates that the hyperlink is to be used for downloading a resource.
#      |  - href (string; optional): The URL of a linked resource.
#      |  - hrefLang (string; optional): Specifies the language of the linked resource.
#      |  - media (string; optional): Specifies a hint of the media for which the linked resource was designed.
#      |  - rel (string; optional): Specifies the relationship of the target object to the link object.
#      |  - shape (string; optional)
#      |  - target (string; optional)
#      |  - accessKey (string; optional): Defines a keyboard shortcut to activate or add focus to the element.
#      |  - className (string; optional): Often used with CSS to style elements with common properties.
#      |  - contentEditable (string; optional): Indicates whether the element's content is editable.
#      |  - contextMenu (string; optional): Defines the ID of a <menu> element which will serve as the element's context menu.
#      |  - dir (string; optional): Defines the text direction. Allowed values are ltr (Left-To-Right) or rtl (Right-To-Left)
#      |  - draggable (string; optional): Defines whether the element can be dragged.
#      |  - hidden (a value equal to: 'hidden', 'HIDDEN' | boolean; optional): Prevents rendering of given element, while keeping child elements, e.g. script elements, active.
#      |  - lang (string; optional): Defines the language used in the element.
#      |  - spellCheck (string; optional): Indicates whether spell checking is allowed for the element.
#      |  - style (dict; optional): Defines CSS styles which will override styles previously set.
#      |  - tabIndex (string; optional): Overrides the browser's default tab order and follows the one specified instead.
#      |  - title (string; optional): Text to be displayed in a tooltip when hovering over the element.
#      |  - loading_state (dict; optional): Object that holds the loading state object coming from dash-renderer. loading_state has the following type: dict containing keys 'is_loading', 'prop_name', 'component_name'.
#      |  Those keys have the following types:
#      |    - is_loading (boolean; optional): Determines if the component is loading or not
#      |    - prop_name (string; optional): Holds which property is loading
#      |    - component_name (string; optional): Holds the name of the component that is loading
#      |
#      |  Method resolution order:
#      |      Area
#      |      dash.development.base_component.Component
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__ = wrapper(self, children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, alt=undefined, coords=undefined, download=undefined, href=undefined, hrefLang=undefined, media=undefined, rel=undefined, shape=undefined, target=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from dash.development.base_component.Component:
#      |
#      |  __delitem__(self, id)
#      |      Delete items by ID in the tree of children.
#      |
#      |  __getitem__(self, id)
#      |      Recursively find the element with the given ID through the tree of
#      |      children.
#      |
#      |  __iter__(self)
#      |      Yield IDs in the tree of children.
#      |
#      |  __len__(self)
#      |      Return the number of items in the tree.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __setitem__(self, id, item)
#      |      Set an element by its ID.
#      |
#      |  to_plotly_json(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from dash.development.base_component.Component:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from dash.development.base_component.Component:
#      |
#      |  REQUIRED = required
#      |
#      |  UNDEFINED = undefined
#
#     class Article(dash.development.base_component.Component)
#      |  Article(children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  An Article component.
#      |  Article is a wrapper for the <article> HTML5 element.
#      |  For detailed attribute info see:
#      |  https://developer.mozilla.org/en-US/docs/Web/HTML/Element/article
#      |
#      |  Keyword arguments:
#      |  - children (a list of or a singular dash component, string or number; optional): The children of this component
#      |  - id (string; optional): The ID of this component, used to identify dash components
#      |  in callbacks. The ID needs to be unique across all of the
#      |  components in an app.
#      |  - n_clicks (number; default 0): An integer that represents the number of times
#      |  that this element has been clicked on.
#      |  - n_clicks_timestamp (number; default -1): An integer that represents the time (in ms since 1970)
#      |  at which n_clicks changed. This can be used to tell
#      |  which button was changed most recently.
#      |  - key (string; optional): A unique identifier for the component, used to improve
#      |  performance by React.js while rendering components
#      |  See https://reactjs.org/docs/lists-and-keys.html for more info
#      |  - role (string; optional): The ARIA role attribute
#      |  - data-* (string; optional): A wildcard data attribute
#      |  - aria-* (string; optional): A wildcard aria attribute
#      |  - accessKey (string; optional): Defines a keyboard shortcut to activate or add focus to the element.
#      |  - className (string; optional): Often used with CSS to style elements with common properties.
#      |  - contentEditable (string; optional): Indicates whether the element's content is editable.
#      |  - contextMenu (string; optional): Defines the ID of a <menu> element which will serve as the element's context menu.
#      |  - dir (string; optional): Defines the text direction. Allowed values are ltr (Left-To-Right) or rtl (Right-To-Left)
#      |  - draggable (string; optional): Defines whether the element can be dragged.
#      |  - hidden (a value equal to: 'hidden', 'HIDDEN' | boolean; optional): Prevents rendering of given element, while keeping child elements, e.g. script elements, active.
#      |  - lang (string; optional): Defines the language used in the element.
#      |  - spellCheck (string; optional): Indicates whether spell checking is allowed for the element.
#      |  - style (dict; optional): Defines CSS styles which will override styles previously set.
#      |  - tabIndex (string; optional): Overrides the browser's default tab order and follows the one specified instead.
#      |  - title (string; optional): Text to be displayed in a tooltip when hovering over the element.
#      |  - loading_state (dict; optional): Object that holds the loading state object coming from dash-renderer. loading_state has the following type: dict containing keys 'is_loading', 'prop_name', 'component_name'.
#      |  Those keys have the following types:
#      |    - is_loading (boolean; optional): Determines if the component is loading or not
#      |    - prop_name (string; optional): Holds which property is loading
#      |    - component_name (string; optional): Holds the name of the component that is loading
#      |
#      |  Method resolution order:
#      |      Article
#      |      dash.development.base_component.Component
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__ = wrapper(self, children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from dash.development.base_component.Component:
#      |
#      |  __delitem__(self, id)
#      |      Delete items by ID in the tree of children.
#      |
#      |  __getitem__(self, id)
#      |      Recursively find the element with the given ID through the tree of
#      |      children.
#      |
#      |  __iter__(self)
#      |      Yield IDs in the tree of children.
#      |
#      |  __len__(self)
#      |      Return the number of items in the tree.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __setitem__(self, id, item)
#      |      Set an element by its ID.
#      |
#      |  to_plotly_json(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from dash.development.base_component.Component:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from dash.development.base_component.Component:
#      |
#      |  REQUIRED = required
#      |
#      |  UNDEFINED = undefined
#
#     class Aside(dash.development.base_component.Component)
#      |  Aside(children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  An Aside component.
#      |  Aside is a wrapper for the <aside> HTML5 element.
#      |  For detailed attribute info see:
#      |  https://developer.mozilla.org/en-US/docs/Web/HTML/Element/aside
#      |
#      |  Keyword arguments:
#      |  - children (a list of or a singular dash component, string or number; optional): The children of this component
#      |  - id (string; optional): The ID of this component, used to identify dash components
#      |  in callbacks. The ID needs to be unique across all of the
#      |  components in an app.
#      |  - n_clicks (number; default 0): An integer that represents the number of times
#      |  that this element has been clicked on.
#      |  - n_clicks_timestamp (number; default -1): An integer that represents the time (in ms since 1970)
#      |  at which n_clicks changed. This can be used to tell
#      |  which button was changed most recently.
#      |  - key (string; optional): A unique identifier for the component, used to improve
#      |  performance by React.js while rendering components
#      |  See https://reactjs.org/docs/lists-and-keys.html for more info
#      |  - role (string; optional): The ARIA role attribute
#      |  - data-* (string; optional): A wildcard data attribute
#      |  - aria-* (string; optional): A wildcard aria attribute
#      |  - accessKey (string; optional): Defines a keyboard shortcut to activate or add focus to the element.
#      |  - className (string; optional): Often used with CSS to style elements with common properties.
#      |  - contentEditable (string; optional): Indicates whether the element's content is editable.
#      |  - contextMenu (string; optional): Defines the ID of a <menu> element which will serve as the element's context menu.
#      |  - dir (string; optional): Defines the text direction. Allowed values are ltr (Left-To-Right) or rtl (Right-To-Left)
#      |  - draggable (string; optional): Defines whether the element can be dragged.
#      |  - hidden (a value equal to: 'hidden', 'HIDDEN' | boolean; optional): Prevents rendering of given element, while keeping child elements, e.g. script elements, active.
#      |  - lang (string; optional): Defines the language used in the element.
#      |  - spellCheck (string; optional): Indicates whether spell checking is allowed for the element.
#      |  - style (dict; optional): Defines CSS styles which will override styles previously set.
#      |  - tabIndex (string; optional): Overrides the browser's default tab order and follows the one specified instead.
#      |  - title (string; optional): Text to be displayed in a tooltip when hovering over the element.
#      |  - loading_state (dict; optional): Object that holds the loading state object coming from dash-renderer. loading_state has the following type: dict containing keys 'is_loading', 'prop_name', 'component_name'.
#      |  Those keys have the following types:
#      |    - is_loading (boolean; optional): Determines if the component is loading or not
#      |    - prop_name (string; optional): Holds which property is loading
#      |    - component_name (string; optional): Holds the name of the component that is loading
#      |
#      |  Method resolution order:
#      |      Aside
#      |      dash.development.base_component.Component
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__ = wrapper(self, children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from dash.development.base_component.Component:
#      |
#      |  __delitem__(self, id)
#      |      Delete items by ID in the tree of children.
#      |
#      |  __getitem__(self, id)
#      |      Recursively find the element with the given ID through the tree of
#      |      children.
#      |
#      |  __iter__(self)
#      |      Yield IDs in the tree of children.
#      |
#      |  __len__(self)
#      |      Return the number of items in the tree.
#      |
# ...
#      |  - accessKey (string; optional): Defines a keyboard shortcut to activate or add focus to the element.
#      |  - className (string; optional): Often used with CSS to style elements with common properties.
#      |  - contentEditable (string; optional): Indicates whether the element's content is editable.
#      |  - contextMenu (string; optional): Defines the ID of a <menu> element which will serve as the element's context menu.
#      |  - dir (string; optional): Defines the text direction. Allowed values are ltr (Left-To-Right) or rtl (Right-To-Left)
#      |  - draggable (string; optional): Defines whether the element can be dragged.
#      |  - hidden (a value equal to: 'hidden', 'HIDDEN' | boolean; optional): Prevents rendering of given element, while keeping child elements, e.g. script elements, active.
#      |  - lang (string; optional): Defines the language used in the element.
#      |  - spellCheck (string; optional): Indicates whether spell checking is allowed for the element.
#      |  - style (dict; optional): Defines CSS styles which will override styles previously set.
#      |  - tabIndex (string; optional): Overrides the browser's default tab order and follows the one specified instead.
#      |  - title (string; optional): Text to be displayed in a tooltip when hovering over the element.
#      |  - loading_state (dict; optional): Object that holds the loading state object coming from dash-renderer. loading_state has the following type: dict containing keys 'is_loading', 'prop_name', 'component_name'.
#      |  Those keys have the following types:
#      |    - is_loading (boolean; optional): Determines if the component is loading or not
#      |    - prop_name (string; optional): Holds which property is loading
#      |    - component_name (string; optional): Holds the name of the component that is loading
#      |
#      |  Method resolution order:
#      |      Video
#      |      dash.development.base_component.Component
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__ = wrapper(self, children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, autoPlay=undefined, controls=undefined, crossOrigin=undefined, height=undefined, loop=undefined, muted=undefined, poster=undefined, preload=undefined, src=undefined, width=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from dash.development.base_component.Component:
#      |
#      |  __delitem__(self, id)
#      |      Delete items by ID in the tree of children.
#      |
#      |  __getitem__(self, id)
#      |      Recursively find the element with the given ID through the tree of
#      |      children.
#      |
#      |  __iter__(self)
#      |      Yield IDs in the tree of children.
#      |
#      |  __len__(self)
#      |      Return the number of items in the tree.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __setitem__(self, id, item)
#      |      Set an element by its ID.
#      |
#      |  to_plotly_json(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from dash.development.base_component.Component:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from dash.development.base_component.Component:
#      |
#      |  REQUIRED = required
#      |
#      |  UNDEFINED = undefined
#
#     class Wbr(dash.development.base_component.Component)
#      |  Wbr(children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  A Wbr component.
#      |  Wbr is a wrapper for the <wbr> HTML5 element.
#      |  For detailed attribute info see:
#      |  https://developer.mozilla.org/en-US/docs/Web/HTML/Element/wbr
#      |
#      |  Keyword arguments:
#      |  - children (a list of or a singular dash component, string or number; optional): The children of this component
#      |  - id (string; optional): The ID of this component, used to identify dash components
#      |  in callbacks. The ID needs to be unique across all of the
#      |  components in an app.
#      |  - n_clicks (number; default 0): An integer that represents the number of times
#      |  that this element has been clicked on.
#      |  - n_clicks_timestamp (number; default -1): An integer that represents the time (in ms since 1970)
#      |  at which n_clicks changed. This can be used to tell
#      |  which button was changed most recently.
#      |  - key (string; optional): A unique identifier for the component, used to improve
#      |  performance by React.js while rendering components
#      |  See https://reactjs.org/docs/lists-and-keys.html for more info
#      |  - role (string; optional): The ARIA role attribute
#      |  - data-* (string; optional): A wildcard data attribute
#      |  - aria-* (string; optional): A wildcard aria attribute
#      |  - accessKey (string; optional): Defines a keyboard shortcut to activate or add focus to the element.
#      |  - className (string; optional): Often used with CSS to style elements with common properties.
#      |  - contentEditable (string; optional): Indicates whether the element's content is editable.
#      |  - contextMenu (string; optional): Defines the ID of a <menu> element which will serve as the element's context menu.
#      |  - dir (string; optional): Defines the text direction. Allowed values are ltr (Left-To-Right) or rtl (Right-To-Left)
#      |  - draggable (string; optional): Defines whether the element can be dragged.
#      |  - hidden (a value equal to: 'hidden', 'HIDDEN' | boolean; optional): Prevents rendering of given element, while keeping child elements, e.g. script elements, active.
#      |  - lang (string; optional): Defines the language used in the element.
#      |  - spellCheck (string; optional): Indicates whether spell checking is allowed for the element.
#      |  - style (dict; optional): Defines CSS styles which will override styles previously set.
#      |  - tabIndex (string; optional): Overrides the browser's default tab order and follows the one specified instead.
#      |  - title (string; optional): Text to be displayed in a tooltip when hovering over the element.
#      |  - loading_state (dict; optional): Object that holds the loading state object coming from dash-renderer. loading_state has the following type: dict containing keys 'is_loading', 'prop_name', 'component_name'.
#      |  Those keys have the following types:
#      |    - is_loading (boolean; optional): Determines if the component is loading or not
#      |    - prop_name (string; optional): Holds which property is loading
#      |    - component_name (string; optional): Holds the name of the component that is loading
#      |
#      |  Method resolution order:
#      |      Wbr
#      |      dash.development.base_component.Component
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__ = wrapper(self, children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from dash.development.base_component.Component:
#      |
#      |  __delitem__(self, id)
#      |      Delete items by ID in the tree of children.
#      |
#      |  __getitem__(self, id)
#      |      Recursively find the element with the given ID through the tree of
#      |      children.
#      |
#      |  __iter__(self)
#      |      Yield IDs in the tree of children.
#      |
#      |  __len__(self)
#      |      Return the number of items in the tree.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __setitem__(self, id, item)
#      |      Set an element by its ID.
#      |
#      |  to_plotly_json(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from dash.development.base_component.Component:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from dash.development.base_component.Component:
#      |
#      |  REQUIRED = required
#      |
#      |  UNDEFINED = undefined
#
#     class Xmp(dash.development.base_component.Component)
#      |  Xmp(children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  A Xmp component.
#      |  Xmp is a wrapper for the <xmp> HTML5 element.
#      |  For detailed attribute info see:
#      |  https://developer.mozilla.org/en-US/docs/Web/HTML/Element/xmp
#      |
#      |  Keyword arguments:
#      |  - children (a list of or a singular dash component, string or number; optional): The children of this component
#      |  - id (string; optional): The ID of this component, used to identify dash components
#      |  in callbacks. The ID needs to be unique across all of the
#      |  components in an app.
#      |  - n_clicks (number; default 0): An integer that represents the number of times
#      |  that this element has been clicked on.
#      |  - n_clicks_timestamp (number; default -1): An integer that represents the time (in ms since 1970)
#      |  at which n_clicks changed. This can be used to tell
#      |  which button was changed most recently.
#      |  - key (string; optional): A unique identifier for the component, used to improve
#      |  performance by React.js while rendering components
#      |  See https://reactjs.org/docs/lists-and-keys.html for more info
#      |  - role (string; optional): The ARIA role attribute
#      |  - data-* (string; optional): A wildcard data attribute
#      |  - aria-* (string; optional): A wildcard aria attribute
#      |  - accessKey (string; optional): Defines a keyboard shortcut to activate or add focus to the element.
#      |  - className (string; optional): Often used with CSS to style elements with common properties.
#      |  - contentEditable (string; optional): Indicates whether the element's content is editable.
#      |  - contextMenu (string; optional): Defines the ID of a <menu> element which will serve as the element's context menu.
#      |  - dir (string; optional): Defines the text direction. Allowed values are ltr (Left-To-Right) or rtl (Right-To-Left)
#      |  - draggable (string; optional): Defines whether the element can be dragged.
#      |  - hidden (a value equal to: 'hidden', 'HIDDEN' | boolean; optional): Prevents rendering of given element, while keeping child elements, e.g. script elements, active.
#      |  - lang (string; optional): Defines the language used in the element.
#      |  - spellCheck (string; optional): Indicates whether spell checking is allowed for the element.
#      |  - style (dict; optional): Defines CSS styles which will override styles previously set.
#      |  - tabIndex (string; optional): Overrides the browser's default tab order and follows the one specified instead.
#      |  - title (string; optional): Text to be displayed in a tooltip when hovering over the element.
#      |  - loading_state (dict; optional): Object that holds the loading state object coming from dash-renderer. loading_state has the following type: dict containing keys 'is_loading', 'prop_name', 'component_name'.
#      |  Those keys have the following types:
#      |    - is_loading (boolean; optional): Determines if the component is loading or not
#      |    - prop_name (string; optional): Holds which property is loading
#      |    - component_name (string; optional): Holds the name of the component that is loading
#      |
#      |  Method resolution order:
#      |      Xmp
#      |      dash.development.base_component.Component
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__ = wrapper(self, children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from dash.development.base_component.Component:
#      |
#      |  __delitem__(self, id)
#      |      Delete items by ID in the tree of children.
#      |
#      |  __getitem__(self, id)
#      |      Recursively find the element with the given ID through the tree of
#      |      children.
#      |
#      |  __iter__(self)
#      |      Yield IDs in the tree of children.
#      |
#      |  __len__(self)
#      |      Return the number of items in the tree.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __setitem__(self, id, item)
#      |      Set an element by its ID.
#      |
#      |  to_plotly_json(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from dash.development.base_component.Component:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from dash.development.base_component.Component:
#      |
#      |  REQUIRED = required
#      |
#      |  UNDEFINED = undefined
#
# DATA
#     __all__ = ['A', 'Abbr', 'Acronym', 'Address', 'Area', 'Article', 'Asid...
#
# VERSION
#     1.0.2
#
# FILE
#     c:\users\kishore thamilvanan\anaconda3\lib\site-packages\dash_html_components\__init__.py
